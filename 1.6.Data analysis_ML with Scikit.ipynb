# %%
import pandas as pd

df = pd.read_csv("E:/placements/career/python/datasets/diamonds/diamonds.csv", index_col = 0)
df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
df["cut"].unique()
# Out:
# array(['Ideal', 'Premium', 'Good', 'Very Good', 'Fair'], dtype=object)

# %%
# df["cut"].astype("category").cat.codes

# %%
cut_class_dict = {"Fair":1, "Good":2, "Very Good":3, "Premium":4, "Ideal":5}
clarity_dict = {"I3": 1, "I2": 2, "I1": 3, "SI2": 4, "SI1": 5, "VS2": 6, "VS1": 7, "VVS2": 8, "VVS1": 9, "IF": 10, "FL": 11}
color_dict = {"J": 1,"I": 2,"H": 3,"G": 4,"F": 5,"E": 6,"D": 7}

df['cut'] = df['cut'].map(cut_class_dict)
df['clarity'] = df['clarity'].map(clarity_dict)
df['color'] = df['color'].map(color_dict)

df.head()
# Out:
#    carat  cut  color  clarity  depth  table  price     x     y     z
# 1   0.23    5      6        4   61.5   55.0    326  3.95  3.98  2.43
# 2   0.21    4      6        5   59.8   61.0    326  3.89  3.84  2.31
# 3   0.23    2      6        7   56.9   65.0    327  4.05  4.07  2.31
# 4   0.29    4      2        6   62.4   58.0    334  4.20  4.23  2.63
# 5   0.31    2      1        4   63.3   58.0    335  4.34  4.35  2.75

# %%
import sklearn
from sklearn import svm, preprocessing

df = sklearn.utils.shuffle(df)

X = df.drop("price", axis = 1).values
X = preprocessing.scale(X)
y = df['price'].values

test_size = 200

X_train = X[:-test_size]
y_train = y[:-test_size]

X_test = X[-test_size:]
y_test = y[-test_size:]

clf = svm.SVR(kernel = "linear")
clf.fit(X_train,y_train)
# Out:
# SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1,
#   gamma='auto_deprecated', kernel='linear', max_iter=-1, shrinking=True,
#   tol=0.001, verbose=False)

# %%
clf.score(X_test,y_test)
# Out:
# 0.9027164293887784

# %%
for X,y in zip(X_test,y_test):
    print(f"Model: {clf.predict([X])}, Actual: {y}")
# Out:
# Model: [2834.06033433], Actual: 2177
# Model: [1490.15805281], Actual: 1569
# Model: [3088.16617078], Actual: 2686
# Model: [4456.35137321], Actual: 4419
# Model: [5471.06658731], Actual: 5575
# Model: [-503.55029984], Actual: 422
# Model: [-548.18174944], Actual: 421
# Model: [5151.19372888], Actual: 6399
# Model: [1095.67350957], Actual: 789
# Model: [1819.88070459], Actual: 1630
# Model: [2713.89853712], Actual: 2247
# Model: [4691.94951285], Actual: 4171
# Model: [4945.9877429], Actual: 5306
# Model: [5926.85869694], Actual: 4972
# Model: [9835.72717951], Actual: 12874
# Model: [6209.16397256], Actual: 6005
# Model: [2864.21189937], Actual: 2199
# Model: [478.93860984], Actual: 876
# Model: [4248.09147612], Actual: 4258
# Model: [649.56726724], Actual: 756
# Model: [1448.79239476], Actual: 1002
# Model: [8689.85690193], Actual: 11303
# Model: [1195.04113289], Actual: 932
# Model: [-301.32056059], Actual: 473
# Model: [360.69961558], Actual: 812
# ...

# %%
clf2 = svm.SVR(kernel = "rbf")
clf2.fit(X_train,y_train)
# Out:
# C:\Users\Praveen\Anaconda3\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1,
#   gamma='auto_deprecated', kernel='rbf', max_iter=-1, shrinking=True,
#   tol=0.001, verbose=False)

# %%
print(clf2.score(X_test,y_test))

for X,y in zip(X_test,y_test):
    print(f"Model: {clf2.predict([X])}, Actual: {y}")
# Out:
# 0.6894054451699779
# Model: [2725.00006291], Actual: 2177
# Model: [1208.94192772], Actual: 1569
# Model: [2838.87120015], Actual: 2686
# Model: [4488.56856329], Actual: 4419
# Model: [4318.99530534], Actual: 5575
# Model: [757.68939975], Actual: 422
# Model: [1449.86376183], Actual: 421
# Model: [4170.93719844], Actual: 6399
# Model: [1106.64957555], Actual: 789
# Model: [1679.51012428], Actual: 1630
# Model: [2088.81151776], Actual: 2247
# Model: [3572.80952166], Actual: 4171
# Model: [5031.6414699], Actual: 5306
# Model: [5104.19774817], Actual: 4972
# Model: [7399.59749854], Actual: 12874
# Model: [4937.3119519], Actual: 6005
# Model: [2768.82251156], Actual: 2199
# Model: [848.95639671], Actual: 876
# Model: [4017.99764666], Actual: 4258
# Model: [1079.81993054], Actual: 756
# Model: [1423.36069435], Actual: 1002
# Model: [6060.82563493], Actual: 11303
# Model: [1127.15064546], Actual: 932
# Model: [475.25196662], Actual: 473
# Model: [895.93989187], Actual: 812
# ...
